# %%
a=list(input())
print(a)
# Out:
# 123
# ['1', '2', '3']

# %%
a=list(input())
print(a)
# Out:
# 1234
# ['1', '2', '3', '4']

# %%
numbers=[12,23,34,45,"kalai"]
print(numbers[3])
print(numbers[4])
# Out:
# 45
# kalai

# %%
 numbers=[10,20,30,40,"mudhu",True,"kali34",False]
 print(numbers[-1])
 print(numbers[-2])
 print(numbers[-3])
 print(numbers[3])
# Out:
# False
# kali34
# True
# 40

# %%
numbers=[10,20,30,"a","b"]
print(numbers[1:2])
print(numbers[:2])
print(numbers[::2])
print(numbers[::-2])
# Out:
# [20]
# [10, 20]
# [10, 30, 'b']
# ['b', 30, 10]

# %%
a=[1,3,5,6,"magi","+"]
b=[4,5,6,"-"]
c=[9,7,6,]
d=a+b
print(c+d)
# Out:
# [9, 7, 6, 1, 3, 5, 6, 'magi', '+', 4, 5, 6, '-']

# %%
num=[10,20,30,]
print(20 in num)
print(20 not in num)
# Out:
# True
# False

# %%
num=[12,34,5]
num.append("44")
print(num)
# Out:
# [12, 34, 5, '44']

# %%
nums=[1,2,3]
nums.insert(1,100)
print(nums)
# Out:
# [1, 100, 2, 3]

# %%
nums=[1,2,3]
nums.insert(1,22)
print(nums)
# Out:
# [1, 22, 2, 3]

# %%
a=[1,2]
b=[2,3]
a.extend(b)
print(a)
# Out:
# [1, 2, 2, 3]

# %%
n=int(input("enter number of elements:"))
a=[]
for i in range(1,n+1):
    elements=int(input("enter element:"))
    a.append(elements)
print("list:",a)
# Out:
# enter number of elements:5
# enter element:12
# enter element:2
# enter element:2
# enter element:2
# enter element:2
# list: [12, 2, 2, 2, 2]

# %%
list1 =[1,2,3,4]
list2=[1,3,4,5]
common=list(set(list1)&set(list2))
print("common element:",common)
# Out:
# common element: [1, 3, 4]

# %%
list1=[1,2,3,4,6]
list2=[9,5,6,4,]
common=[]
for i in list1:
    if i in list2:
        common.append(i)
print("common element:",common)
# Out:
# common element: [4, 6]
