# %%
nums =[12,23,455,667,78,5,4,55,]
del nums[3]
del nums[4]
print(nums)
# Out:
# [12, 23, 455, 78, 4, 55]

# %%
matrix=[[1,2,36,7],[4,5,6,66]]
del matrix[0][3]
print(matrix[0][2])
print (matrix )
# Out:
# 36
# [[1, 2, 36], [4, 5, 6, 66]]

# %%
data =[12,34,34,34,67,78,"guluguluoooo"]
a,b,c,*d,e=data
print(a,b,c)
print(e)
print(d)
# Out:
# 12 34 34
# guluguluoooo
# [34, 67, 78]

# %%
word=["panana","apple","kiwi","al"]
word.sort(key=len)
print(word)
# Out:
# ['al', 'kiwi', 'apple', 'panana']

# %%
nums=[2,3,4,]
squares=list(map(lambda x:x**3,nums))
print(squares)
# Out:
# [8, 27, 64]
