# %%
import pandas as pd

# %%
a=pd.Series([10,20,30,40,50,60,])
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
a.values
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
a.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
a.name

# %%
a.name="calaries"

# %%
a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: calaries, dtype: int64

# %%
a[0]
# Out:
# np.int64(10)

# %%
a.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
a[0:2]
# Out:
# 0    10
# 1    20
# Name: calaries, dtype: int64

# %%
a[2:4]
# Out:
# 2    30
# 3    40
# Name: calaries, dtype: int64

# %%
#iloc -> location based index
a.iloc[3]
# Out:
# np.int64(40)

# %%
a.iloc[[1,2,3]]
# Out:
# 1    20
# 2    30
# 3    40
# Name: calaries, dtype: int64

# %%
 index=["apple","orange","copico","cared","dongy","waste"]

# %%
a.index=index
a
# Out:
# apple     10
# orange    20
# copico    30
# cared     40
# dongy     50
# waste     60
# Name: calaries, dtype: int64

# %%
a["waste"]
# Out:
# np.int64(60)

# %%
a.iloc[3]
# Out:
# np.int64(40)

# %%
#loc label based indexing
a.loc["apple"]
# Out:
# np.int64(10)

# %%
data ={
    "name":["arun","kumar","velu","kali","muththu"],
    "age":[20,23,43,23,23],
    "department":["HR","IT","HR","IT","IT"],
    "salary":[1000,28000,12000,21000,37000]
       }

# %%
data
# Out:
# {'name': ['arun', 'kumar', 'velu', 'kali', 'muththu'],
#  'age': [20, 23, 43, 23, 23],
#  'department': ['HR', 'IT', 'HR', 'IT', 'IT'],
#  'salary': [1000, 28000, 12000, 21000, 37000]}

# %%
df=pd.DataFrame(data)
df
# Out:
#       name  age department  salary
# 0     arun   20         HR    1000
# 1    kumar   23         IT   28000
# 2     velu   43         HR   12000
# 3     kali   23         IT   21000
# 4  muththu   23         IT   37000

# %%
df.head(2)
# Out:
#     name  age department  salary
# 0   arun   20         HR    1000
# 1  kumar   23         IT   28000

# %%
df.tail(3)
# Out:
#       name  age department  salary
# 2     velu   43         HR   12000
# 3     kali   23         IT   21000
# 4  muththu   23         IT   37000

# %%
df.iloc[0:1,:3]
# Out:
#    name  age department
# 0  arun   20         HR

# %%
df.loc[0:1,["name","salary"]]
# Out:
#     name  salary
# 0   arun    1000
# 1  kumar   28000

# %%
df["age"]
# Out:
# 0    20
# 1    23
# 2    43
# 3    23
# 4    23
# Name: age, dtype: int64

# %%
df.drop("age" ,axis=1)
# Out:
#       name department  salary
# 0     arun         HR    1000
# 1    kumar         IT   28000
# 2     velu         HR   12000
# 3     kali         IT   21000
# 4  muththu         IT   37000

# %%
data
# Out:
# {'name': ['arun', 'kumar', 'velu', 'kali', 'muththu'],
#  'age': [20, 23, 43, 23, 23],
#  'department': ['HR', 'IT', 'HR', 'IT', 'IT'],
#  'salary': [1000, 28000, 12000, 21000, 37000]}

# %%
df
# Out:
#       name  age department  salary
# 0     arun   20         HR    1000
# 1    kumar   23         IT   28000
# 2     velu   43         HR   12000
# 3     kali   23         IT   21000
# 4  muththu   23         IT   37000

# %%
df.drop("salary" ,axis=1,)
# Out:
#       name  age department
# 0     arun   20         HR
# 1    kumar   23         IT
# 2     velu   43         HR
# 3     kali   23         IT
# 4  muththu   23         IT

# %%
df
# Out:
#       name  age department  salary
# 0     arun   20         HR    1000
# 1    kumar   23         IT   28000
# 2     velu   43         HR   12000
# 3     kali   23         IT   21000
# 4  muththu   23         IT   37000

# %%
df
# Out:
#       name  age department  salary
# 0     arun   20         HR    1000
# 1    kumar   23         IT   28000
# 2     velu   43         HR   12000
# 3     kali   23         IT   21000
# 4  muththu   23         IT   37000

# %%
df.shape
# Out:
# (5, 4)

# %%
df.info
# Out:
# <bound method DataFrame.info of       name  age department  salary
# 0     arun   20         HR    1000
# 1    kumar   23         IT   28000
# 2     velu   43         HR   12000
# 3     kali   23         IT   21000
# 4  muththu   23         IT   37000>

# %%
df.describe()
# Out:
#              age        salary
# count   5.000000      5.000000
# mean   26.400000  19800.000000
# std     9.370165  13953.494186
# min    20.000000   1000.000000
# 25%    23.000000  12000.000000
# 50%    23.000000  21000.000000
# 75%    23.000000  28000.000000
# max    43.000000  37000.000000

# %%
df["salary"]=df["salary"]+5000

# %%
df
# Out:
#       name  age department  salary
# 0     arun   20         HR    6000
# 1    kumar   23         IT   33000
# 2     velu   43         HR   17000
# 3     kali   23         IT   26000
# 4  muththu   23         IT   42000

# %%
df["salary"]
# Out:
# 0     6000
# 1    33000
# 2    17000
# 3    26000
# 4    42000
# Name: salary, dtype: int64

# %%
df
# Out:
#       name  age department  salary
# 0     arun   20         HR    6000
# 1    kumar   23         IT   33000
# 2     velu   43         HR   17000
# 3     kali   23         IT   26000
# 4  muththu   23         IT   42000

# %%
 df.rename(columns={"department":"dept"},inplace=True)

# %%
df
# Out:
#       name  age dept  salary
# 0     arun   20   HR    6000
# 1    kumar   23   IT   33000
# 2     velu   43   HR   17000
# 3     kali   23   IT   26000
# 4  muththu   23   IT   42000

# %%
df["dept"].unique()
# Out:
# array(['HR', 'IT'], dtype=object)

# %%
df["dept"].value_counts()
# Out:
# dept
# IT    3
# HR    2
# Name: count, dtype: int64

# %%
df["promoted salary"]=df["salary"]+200

# %%
df
# Out:
#       name  age dept  salary  promoted salary
# 0     arun   20   HR    6000             6200
# 1    kumar   23   IT   33000            33200
# 2     velu   43   HR   17000            17200
# 3     kali   23   IT   26000            26200
# 4  muththu   23   IT   42000            42200

# %%
df.isnull().sum()
# Out:
# name               0
# age                0
# dept               0
# salary             0
# promoted salary    0
# dtype: int64

# %%
df.dropna()
# Out:
#       name  age dept  salary  promoted salary
# 0     arun   20   HR    6000             6200
# 1    kumar   23   IT   33000            33200
# 2     velu   43   HR   17000            17200
# 3     kali   23   IT   26000            26200
# 4  muththu   23   IT   42000            42200

# %%
df.dropna( how="any")
# Out:
#       name  age dept  salary  promoted salary
# 0     arun   20   HR    6000             6200
# 1    kumar   23   IT   33000            33200
# 2     velu   43   HR   17000            17200
# 3     kali   23   IT   26000            26200
# 4  muththu   23   IT   42000            42200

# %%
df.dropna(how="all")
# Out:
#       name  age dept  salary  promoted salary
# 0     arun   20   HR    6000             6200
# 1    kumar   23   IT   33000            33200
# 2     velu   43   HR   17000            17200
# 3     kali   23   IT   26000            26200
# 4  muththu   23   IT   42000            42200

# %%
df.fillna(0)
# Out:
#       name  age dept  salary  promoted salary
# 0     arun   20   HR    6000             6200
# 1    kumar   23   IT   33000            33200
# 2     velu   43   HR   17000            17200
# 3     kali   23   IT   26000            26200
# 4  muththu   23   IT   42000            42200

# %%
df["age"].fillna(df["age"].mean())
# Out:
# 0    20
# 1    23
# 2    43
# 3    23
# 4    23
# Name: age, dtype: int64

# %%
df["salary"].fillna(df["salary"].median())
# Out:
# 0     6000
# 1    33000
# 2    17000
# 3    26000
# 4    42000
# Name: salary, dtype: int64

# %%
df["salary"].fillna(method="ffill")
# Out:
# /tmp/ipykernel_162/4275000142.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["salary"].fillna(method="ffill")
# 0     6000
# 1    33000
# 2    17000
# 3    26000
# 4    42000
# Name: salary, dtype: int64

# %%
df["salary"].fillna(method="bfill")
# Out:
# /tmp/ipykernel_162/3559053075.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["salary"].fillna(method="bfill")
# 0     6000
# 1    33000
# 2    17000
# 3    26000
# 4    42000
# Name: salary, dtype: int64

# %%
#replace
df["name"].replace("arun","kalai")
# Out:
# 0      kalai
# 1      kumar
# 2       velu
# 3       kali
# 4    muththu
# Name: name, dtype: object

# %%
df
# Out:
#       name  age dept  salary  promoted salary
# 0     arun   20   HR    6000             6200
# 1    kumar   23   IT   33000            33200
# 2     velu   43   HR   17000            17200
# 3     kali   23   IT   26000            26200
# 4  muththu   23   IT   42000            42200

# %%
df["name"]=df["name"].replace("arun","kalai")

# %%
df
# Out:
#       name  age dept  salary  promoted salary
# 0    kalai   20   HR    6000             6200
# 1    kumar   23   IT   33000            33200
# 2     velu   43   HR   17000            17200
# 3     kali   23   IT   26000            26200
# 4  muththu   23   IT   42000            42200

# %%
df_dup=df[df.duplicated(keep="first")]
df_dup
# Out:
# Empty DataFrame
# Columns: [name, age, dept, salary, promoted salary]
# Index: []
