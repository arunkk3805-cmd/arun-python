# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,3,4]
y=[1,2,3,4]
plt.plot(x,y)
plt.grid()
plt.show()

# %%
#pyplot api
#univariate - numerical
data = {
    "salary":[1000,2000,3000,3000,4000,5000,6000,7000,]
}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    salary
# 0    1000
# 1    2000
# 2    3000
# 3    3000
# 4    4000

# %%
df.shape
# Out:
# (8, 1)

# %%
from matplotlib.lines import lineStyles
#lone plot
plt.plot(df["salary"],color="red",marker="*",linestyle=":" ,linewidth="2" )
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#histogram
plt.hist(df["salary"],bins=5,color = "yellow")
plt.grid
plt.show()

# %%
#poxplot:
plt.boxplot(df["salary"])
plt.show()

# %%
df.loc[20]=0

# %%
plt.boxplot(df["salary"])
plt.show()

# %%
df.drop(index=20,inplace=True)

# %%
df.shape
# Out:
# (8, 1)

# %%
df["dept"]=['hr,''it','md','it','tl']*2

# %%
df.dept
# Out:
# 0    hr,it
# 1       md
# 2       it
# 3       tl
# 4    hr,it
# 5       md
# 6       it
# 7       tl
# Name: dept, dtype: object

# %%
df.head()
# Out:
#    salary   dept
# 0    1000  hr,it
# 1    2000     md
# 2    3000     it
# 3    3000     tl
# 4    4000  hr,it

# %%
#pie chart
count=df["dept"].value_counts()
plt.pie(count, labels=count.index, autopct="%1.0f", )#explot[,0,0.1,0] seprate the value
plt.axis("equal")#full sercle
plt.show()

# %%
#bar chart

# %%
plt.bar(count.index,count,color=["red","green","black","yellow"])
plt.show()

# %%
#bivariate-numarical
df.head()
# Out:
#    salary   dept
# 0    1000  hr,it
# 1    2000     md
# 2    3000     it
# 3    3000     tl
# 4    4000  hr,it

# %%
df["age"]=[12,23,45,56,67,21,23,34]

# %%
df.head()
# Out:
#    salary   dept  age
# 0    1000  hr,it   12
# 1    2000     md   23
# 2    3000     it   45
# 3    3000     tl   56
# 4    4000  hr,it   67

# %%
#scatter plot
plt.scatter(df["salary"],df["age"],color="green",marker="*")
plt.show()

# %%
sort_age=df.sort_values("age")

# %%
 #line plot
 plt.plot(sort_age["salary"],df["age"],color="green",marker="*",linestyle="--",linewidth="2")
 plt.grid()
 plt.show()

# %%
#bar chart
plt.bar(sort_age["salary"],sort_age["age"],color="green",align="center")
plt.grid()
plt.show()

# %%
hr_sal=df[df["dept"]=="hr"]["salary"]
hr_sal
# Out:
# Series([], Name: salary, dtype: int64)

# %%
#bubble plot:
plt.scatter(df["salary"],df["age"],s=df["experience"],color="orange")
plt.show()

# %%
  data2={
      'year':[2020,2021,2022,2023],
      'sales':[100,150,200,250],
      'profit':[20,30,40,50],
      'expenses':[10,20,30,40]
  }

# %%
df2=pd.DataFrame(data)

# %%
plt.plot(df2["year"],df2["sales"],label="sales")
plt.plot(df2["year"],df2["profit"],label="profit")
plt.plot(df2["year"],df2["expenses"],label="expenses")
plt.title("company report")
plt.xlabel("year")
plt.ylabel("amount")
plt.legend()
plt.show()

# %%
df.head()
# Out:
#    salary   dept  age
# 0    1000  hr,it   12
# 1    2000     md   23
# 2    3000     it   45
# 3    3000     tl   56
# 4    4000  hr,it   67

# %%
df["experience"] = [2, 5, 10, 15, 20, 3, 6, 8]

ax=plt.axes(projection="3d")
ax.scatter3D(df["salary"],df["age"],df["experience"])
ax.set_xlabel("salary")
ax.set_ylabel("age")
ax.set_zlabel("experience")
plt. show()

# %%
import plotly.express as px

# %%
fig=px.scatter_3d(df,x="salary",y="age",z="experience")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
